# %%
#import libs
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount("/content/drive")
# !ls "./drive/My Drive/Colab Notebooks/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  ctd-full.csv				  OceanProjectFinal_lim.ipynb
#  DeepwaterHorizon_data_GordonGunter.csv   table_273.csv
# 'FinalProject (2).ipynb'		  Untitled0.ipynb
#  FinalProject-5.ipynb			  Untitled1.ipynb
#  FinalProject.ipynb			  Untitled2.ipynb
#  IndonesiaSea_ctd_lim.csv

# %%
import datetime
import glob
#dimensianlize data
#t = np.array([], dtype=object)
#d = np.array([], dtype=object)
plt.rcParams["figure.figsize"] = [15,9]
dat = np.genfromtxt('./drive/My Drive/Colab Notebooks/ctd-full.csv', delimiter=',', skip_header = 1248, skip_footer = 14614)
#print(prs)
print(dat.shape)
spdsound = dat[:,17]
depth = dat[:,2]
plt.gca().invert_yaxis()
#print(tmp)
plt.plot(spdsound, depth,'b', linewidth=2)
#t = np.concatenate([t, time])
#d = np.concatenate([d, dens])
#plt.plot(time, dens)

#u = np.hstack([t.reshape(-1,1), d.reshape(-1,1)])
#plt.plot(t, d)
#u = np.array(sorted(u, key= lambda x: x[0])) 
#plt.plot(u[:,0], u[:,1])
plt.title('Chukchi Sea - Speed of Sound Profile')
plt.xlabel('Speed of Sound (m/s)')
plt.ylabel('Depth (m)')
plt.show()
# Out:
# (894, 18)

# %%
import datetime
import glob
#dimensianlize data
#t = np.array([], dtype=object)
#d = np.array([], dtype=object)
plt.rcParams["figure.figsize"] = [15,9]
dat = np.genfromtxt('./drive/My Drive/Colab Notebooks/IndonesiaSea_ctd_lim.csv', delimiter=',', skip_header = 15662, skip_footer = 51774)
#print(prs)
print(dat.shape)
spdsound = dat[:,14]
depth = dat[:,1]
plt.gca().invert_yaxis()
#print(tmp)
plt.plot(spdsound, depth,'b', linewidth=2)
#t = np.concatenate([t, time])
#d = np.concatenate([d, dens])
#plt.plot(time, dens)

#u = np.hstack([t.reshape(-1,1), d.reshape(-1,1)])
#plt.plot(t, d)
#u = np.array(sorted(u, key= lambda x: x[0])) 
#plt.plot(u[:,0], u[:,1])
plt.title('Indonesian Sea - Speed of Sound Profile')
plt.xlabel('Speed of Sound (m/s)')
plt.ylabel('Depth (m)')
plt.show()
# Out:
# (1966, 15)

# %%
import datetime
import glob
#dimensianlize data
#t = np.array([], dtype=object)
#d = np.array([], dtype=object)
plt.rcParams["figure.figsize"] = [15,9]
dat = np.genfromtxt('./drive/My Drive/Colab Notebooks/table_273.csv', encoding = "ISO-8859-1", delimiter=',', skip_header = 691802, skip_footer = 353479)
#print(prs)
print(dat.shape)
spdsound = dat[:,15]
depth = dat[:,7]
plt.gca().invert_yaxis()
#print(tmp)
plt.plot(spdsound, depth,'b', linewidth=2)
#t = np.concatenate([t, time])
#d = np.concatenate([d, dens])
#plt.plot(time, dens)

#u = np.hstack([t.reshape(-1,1), d.reshape(-1,1)])
#plt.plot(t, d)
#u = np.array(sorted(u, key= lambda x: x[0])) 
#plt.plot(u[:,0], u[:,1])
plt.title('Palmer Station Antartica - Speed of Sound Profile')
plt.xlabel('Speed of Sound (m/s)')
plt.ylabel('Depth (m)')
plt.show()
# Out:
# (3295, 16)
